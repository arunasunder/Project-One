# %%
import os
import pandas as pd
#DF_2012=pd.read_sas("LLCP2012.XPT")

# %%
inputfilepath=os.path.join("..","raw_data","LLCP2014.XPT")
DF_2014=pd.read_sas(inputfilepath)

# %%
NDF_2014=DF_2014[["IDATE","_STATE", "SEX", "_AGEG5YR","MENTHLTH","EMPLOY1","SLEPTIM1",
                    "_RFHLTH","_HCVU651","CVDINFR4","CVDCRHD4","CVDSTRK3", "ASTHNOW","CHCSCNCR", 
                    "CHCOCNCR","CHCCOPD1","_DRDXAR1","ADDEPEV2", "CHCKIDNY", "DIABETE3","PREGNANT", 
                    "QLMENTL2","QLSTRES2","_RFSMOK3", "_RFDRHV4","_PRACE1",
                    "EMTSUPRT", "LSATISFY","MSCODE","_TOTINDA","_INCOMG","_BMI5CAT"]]
NDF_2014.head()
# Out:
#          IDATE  _STATE  SEX  _AGEG5YR  MENTHLTH  EMPLOY1  SLEPTIM1  _RFHLTH  \
# 0  b'01172014'     1.0  2.0       9.0       5.0      8.0       9.0      2.0
# 1  b'01072014'     1.0  1.0      11.0      14.0      8.0       6.0      1.0
# 2  b'01092014'     1.0  1.0       7.0      88.0      1.0       8.0      1.0
# 3  b'01072014'     1.0  2.0      10.0      77.0      7.0       8.0      1.0
# 4  b'01162014'     1.0  2.0      10.0      88.0      7.0       8.0      1.0
#
#    _HCVU651  CVDINFR4    ...     QLSTRES2  _RFSMOK3  _RFDRHV4  _PRACE1  \
# 0       1.0       1.0    ...          NaN       1.0       1.0      1.0
# 1       9.0       2.0    ...          NaN       1.0       1.0      1.0
# 2       1.0       2.0    ...          NaN       1.0       1.0      1.0
# 3       9.0       2.0    ...          NaN       1.0       1.0      1.0
# 4       9.0       2.0    ...          NaN       1.0       1.0      1.0
#
#    EMTSUPRT  LSATISFY  MSCODE  _TOTINDA  _INCOMG  _BMI5CAT
# 0       NaN       NaN     5.0       2.0      5.0       3.0
# 1       NaN       NaN     3.0       1.0      2.0       2.0
# 2       NaN       NaN     3.0       1.0      5.0       4.0
# 3       NaN       NaN     5.0       2.0      3.0       4.0
# 4       NaN       NaN     2.0       2.0      2.0       4.0
#
# [5 rows x 32 columns]

# %%
NDF_2014.columns
# Out:
# Index(['IDATE', '_STATE', 'SEX', '_AGEG5YR', 'MENTHLTH', 'EMPLOY1', 'SLEPTIM1',
#        '_RFHLTH', '_HCVU651', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3', 'ASTHNOW',
#        'CHCSCNCR', 'CHCOCNCR', 'CHCCOPD1', '_DRDXAR1', 'ADDEPEV2', 'CHCKIDNY',
#        'DIABETE3', 'PREGNANT', 'QLMENTL2', 'QLSTRES2', '_RFSMOK3', '_RFDRHV4',
#        '_PRACE1', 'EMTSUPRT', 'LSATISFY', 'MSCODE', '_TOTINDA', '_INCOMG',
#        '_BMI5CAT'],
#       dtype='object')

# %%
# Convert date from byte to string
NDF_2014["IDATE"]=NDF_2014["IDATE"].str.decode("utf-8")
NDF_2014["SEX"]=NDF_2014["SEX"].replace({1.0:"M",2.0:"F"})


NDF_2014["_AGEG5YR"]=NDF_2014["_AGEG5YR"].replace({1.0:"18-24",2.0:"25-29",3.0:"30-34",4.0:"35-39",5.0:"40-44",
                                                  6.0:"45-49",7.0:"50-54",8.0:"55-59",9.0:"60-64",10.0:"65-69",
                                                  11.0:"70-74",12.0:"75-79",13.0:"80+",14.0:"",None:0})
NDF_2014["EMPLOY1"]=NDF_2014["EMPLOY1"].replace({1.0:"Employed", 2.0:"Self-Employed", 3.0:"Out of work",
                                               4.0:"Out of work", 5.0:"Homemaker", 6.0:"Student",
                                               7.0:"Retired", 8.0:"Unable to work", 9.0:0,None:0})

NDF_2014["_PRACE1"]=NDF_2014["_PRACE1"].replace({1.0:"White",2.0:"Black or African American",3.0:"Asian",
                                               4.0:"Native Hawaiian or Other Pacific Islander",
                                               5.0:"American Indian, Alaska Native",6.0:"Other",
                                               7.0:0, 8.0:"Multiracial",9.0:0})
NDF_2014["MENTHLTH"]=NDF_2014["MENTHLTH"].replace({88:0,77:0,99:0,None:0})
NDF_2014["_RFHLTH"]=NDF_2014["_RFHLTH"].replace({1:"Good",2:"Poor",9:0,None:0})
#NDF_2014["HLTHPLN1"]=NDF_2014["HLTHPLN1"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CVDINFR4"]=NDF_2014["CVDINFR4"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CVDCRHD4"]=NDF_2014["CVDCRHD4"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CVDSTRK3"]=NDF_2014["CVDSTRK3"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["ASTHNOW"]=NDF_2014["ASTHNOW"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CHCSCNCR"]=NDF_2014["CHCSCNCR"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CHCOCNCR"]=NDF_2014["CHCOCNCR"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CHCCOPD1"]=NDF_2014["CHCCOPD1"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["_DRDXAR1"]=NDF_2014["_DRDXAR1"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["ADDEPEV2"]=NDF_2014["ADDEPEV2"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["CHCKIDNY"]=NDF_2014["CHCKIDNY"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["DIABETE3"]=NDF_2014["DIABETE3"].replace({1:"Y", 2:"N", 3:"N", 4:"N", 7:0, 9:0,None:0})


NDF_2014["PREGNANT"]=NDF_2014["PREGNANT"].replace({1:"Y", 2:"N", 7:0, 9:0,None:0})
NDF_2014["_BMI5CAT"]=NDF_2014["_BMI5CAT"].replace({4:"Obese",3:"Overweight",2:"Normal Weight",1:"Underweight",None:0})
NDF_2014["QLMENTL2"]=NDF_2014["QLMENTL2"].replace({88:0,77:0,99:0,None:0})
NDF_2014["_TOTINDA"]=NDF_2014["_TOTINDA"].replace({2:"N",1:"Y",9:0,None:0})
NDF_2014["QLSTRES2"]=NDF_2014["QLSTRES2"].replace({88:0,77:0,99:0,None:0})
#NDF_2014["_RFSMOK3"]=NDF_2014["_RFSMOK3"].replace({1.0:"Everyday",2.0:"Some days",3.0:"None",
                                                   #7.0:0,9.0:0,None:0})
#NDF_2014["_RFDRHV4"]=NDF_2014["_RFDRHV4"].replace({77:0,99:0,None:0})
NDF_2014["MSCODE"]=NDF_2014["MSCODE"].replace({5:"Rural",3:"Urban",2:"Urban",1:"Urban",None:"Rural"})

NDF_2014["LSATISFY"]=NDF_2014["LSATISFY"].replace({88:0,77:0,99:0,None:0})
NDF_2014["EMTSUPRT"]=NDF_2014["EMTSUPRT"].replace({88:0,77:0,99:0,None:0})

NDF_2014["_INCOMG"]=NDF_2014["_INCOMG"].replace({1:"<15000", 2:"15000-<25000",
                                                 3:"25000-<35000", 4:"35000-<50000",
                                                 5:"50000+",9:0,None:0})



#NDF_2014["_AGEG5YR"].head()
# Out:
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\aswat\Anaconda3\envs\newPythonData\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
NDF_2014=NDF_2014.rename(columns={"_STATE":"fips"})
outputfilepath=os.path.join("..","raw_data","output","fipstostate.csv")
FIP_State=pd.read_csv(outputfilepath)
FIP_State.head()
NDF_2014=NDF_2014.merge(FIP_State,on="fips")
NDF_2014.drop("fips",axis=1,inplace=True)
NDF_2014["Chronic_Disease"]=""

# %%
for index, row in NDF_2014.iterrows():
    chron_dep=0
    if row["CVDINFR4"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CVDCRHD4"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CVDSTRK3"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["ASTHNOW"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CHCSCNCR"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CHCOCNCR"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CHCCOPD1"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["_DRDXAR1"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["CHCKIDNY"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    if row["DIABETE3"]=="Y":
        chron_dep+=1
    else:
        chron_dep+=0
    NDF_2014.set_value(index, "Chronic_Disease",chron_dep)
NDF_2014.drop(["CVDINFR4","CVDCRHD4","CVDSTRK3","ASTHNOW","CHCSCNCR",
          "CHCOCNCR","CHCCOPD1","_DRDXAR1","CHCKIDNY","DIABETE3"],axis=1,inplace=True)

# %%
NDF_2014=NDF_2014.rename(columns={"_AGEG5YR":"Age_Range",
                                  "state_abbr":"State","SEX":"Gender",
                                  "MSCODE":"MetroStatusCode",
                                    "EMPLOY1":"Employment_Status",
                                  "MENTHLTH":"Mental_Health_Factor", 
                                  "_RFHLTH":"General_Health",
                                    "_HCVU651":"Health_Coverage",
                                  "ADDEPEV2":"Chronic_Depression",
                                  "QLACTLM2":"DISABLED",
                                  "SLEPTIM1":"Sleep_Hours",
                                    "QLMENTL2":"Depressed_Days",
                                  "QLSTRES2":"Stress_Days", 
                                  "_RFSMOK3":"Smoke_Frequency",
                                    "_RFDRHV4":"Alcohol_Frequency",
                                  "PREGNANT":"Pregnant",
                                    "IDATE":"Date","_PRACE1":"Race",
                                  "_TOTINDA":"Physical_Activity",
                                  "_INCOMG":"Income","_BMI5CAT":"BMI",
                                 "EMTSUPRT":"EmotionalSupport_Availability",
                                  "LSATISFY":"LifeSatisfaction_Level",
                                  

})

# %%
NDF_2014.head()
# Out:
#        Date Gender Age_Range  Mental_Health_Factor Employment_Status  \
# 0  01172014      F     60-64                   5.0    Unable to work
# 1  01072014      M     70-74                  14.0    Unable to work
# 2  01092014      M     50-54                   0.0          Employed
# 3  01072014      F     65-69                   0.0           Retired
# 4  01162014      F     65-69                   0.0           Retired
#
#    Sleep_Hours General_Health  Health_Coverage Chronic_Depression Pregnant  \
# 0          9.0           Poor              1.0                  N        0
# 1          6.0           Good              9.0                  Y        0
# 2          8.0           Good              1.0                  N        0
# 3          8.0           Good              9.0                  Y        0
# 4          8.0           Good              9.0                  N        0
#
#         ...        Alcohol_Frequency   Race  EmotionalSupport_Availability  \
# 0       ...                      1.0  White                            0.0
# 1       ...                      1.0  White                            0.0
# 2       ...                      1.0  White                            0.0
# 3       ...                      1.0  White                            0.0
# 4       ...                      1.0  White                            0.0
#
#    LifeSatisfaction_Level MetroStatusCode  Physical_Activity        Income  \
# 0                     0.0           Rural                  N        50000+
# 1                     0.0           Urban                  Y  15000-<25000
# 2                     0.0           Urban                  Y        50000+
# 3                     0.0           Rural                  N  25000-<35000
# 4                     0.0           Urban                  N  15000-<25000
#
#              BMI State Chronic_Disease
# 0     Overweight    AL               6
# 1  Normal Weight    AL               3
# 2          Obese    AL               0
# 3          Obese    AL               4
# 4          Obese    AL               3
#
# [5 rows x 23 columns]

# %%
#NDF_2014.drop("state_abbr_y",axis=1,inplace=True)

outputfilepath=os.path.join("..","raw_data","output","BRFSS_2014.csv")
NDF_2014.to_csv(outputfilepath,index=False)

# %%
NDF_2014.columns
# Out:
# Index(['Date', 'Gender', 'Age_Range', 'Mental_Health_Factor',
#        'Employment_Status', 'Sleep_Hours', 'General_Health', 'Health_Coverage',
#        'Chronic_Depression', 'Pregnant', 'Depressed_Days', 'Stress_Days',
#        'Smoke_Frequency', 'Alcohol_Frequency', 'Race',
#        'EmotionalSupport_Availability', 'LifeSatisfaction_Level',
#        'MetroStatusCode', 'Physical_Activity', 'Income', 'BMI', 'State',
#        'Chronic_Disease'],
#       dtype='object')

# %%
outputfilepath=os.path.join("..","raw_data","output","BRFSS_2014.csv")
brfss_data=pd.read_csv(outputfilepath)
brfss_data.head()
# Out:
#       Date Gender Age_Range  Mental_Health_Factor Employment_Status  \
# 0  1172014      F     60-64                   5.0    Unable to work
# 1  1072014      M     70-74                  14.0    Unable to work
# 2  1092014      M     50-54                   0.0          Employed
# 3  1072014      F     65-69                   0.0           Retired
# 4  1162014      F     65-69                   0.0           Retired
#
#    Sleep_Hours General_Health  Health_Coverage Chronic_Depression Pregnant  \
# 0          9.0           Poor              1.0                  N        0
# 1          6.0           Good              9.0                  Y        0
# 2          8.0           Good              1.0                  N        0
# 3          8.0           Good              9.0                  Y        0
# 4          8.0           Good              9.0                  N        0
#
#         ...        Alcohol_Frequency   Race  EmotionalSupport_Availability  \
# 0       ...                      1.0  White                            0.0
# 1       ...                      1.0  White                            0.0
# 2       ...                      1.0  White                            0.0
# 3       ...                      1.0  White                            0.0
# 4       ...                      1.0  White                            0.0
#
#    LifeSatisfaction_Level MetroStatusCode  Physical_Activity        Income  \
# 0                     0.0           Rural                  N        50000+
# 1                     0.0           Urban                  Y  15000-<25000
# 2                     0.0           Urban                  Y        50000+
# 3                     0.0           Rural                  N  25000-<35000
# 4                     0.0           Urban                  N  15000-<25000
#
#              BMI State Chronic_Disease
# 0     Overweight    AL               6
# 1  Normal Weight    AL               3
# 2          Obese    AL               0
# 3          Obese    AL               4
# 4          Obese    AL               3
#
# [5 rows x 23 columns]
